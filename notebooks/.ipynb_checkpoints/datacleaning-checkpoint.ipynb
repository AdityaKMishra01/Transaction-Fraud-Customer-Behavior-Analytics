# %% [markdown]
# # Data Cleaning & Feature Engineering
#
# ## Objective
#
# The objective of this notebook is to transform the raw transaction dataset into a clean, consistent, and analysis-ready dataset. This includes performing data quality checks, handling inconsistencies, creating meaningful features, and preparing the dataset for Exploratory Data Analysis (EDA), SQL analysis, Power BI dashboards, and the Machine Learning phase.

# %% [markdown]
# # 1. Import Libraries
#
# Import all the required Python libraries that will be used for data cleaning, feature engineering, and data manipulation.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2. Load Dataset
#
# Load the raw transaction dataset into a DataFrame and create a copy to preserve the original data for reference.

# %%
transactions = pd.read_csv('../Data/transaction_2024.csv')

# %% [markdown]
# # 3. Initial Data Inspection
#
# Perform an initial assessment of the dataset by examining its structure, dimensions, data types, summary statistics, and overall data quality before making any modifications.

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   transaction id      250000 non-null  object
#  1   timestamp           250000 non-null  object
#  2   transaction type    250000 non-null  object
#  3   merchant_category   250000 non-null  object
#  4   amount (INR)        250000 non-null  int64
#  5   transaction_status  250000 non-null  object
#  6   sender_age_group    250000 non-null  object
#  7   receiver_age_group  250000 non-null  object
#  8   sender_state        250000 non-null  object
#  9   sender_bank         250000 non-null  object
#  10  receiver_bank       250000 non-null  object
#  11  device_type         250000 non-null  object
#  12  network_type        250000 non-null  object
#  13  fraud_flag          250000 non-null  int64
#  14  hour_of_day         250000 non-null  int64
#  15  day_of_week         250000 non-null  object
#  16  is_weekend          250000 non-null  int64
# dtypes: int64(4), object(13)
# memory usage: 32.4+ MB

# %%
transactions.head(10)
# Out:
#        transaction id           timestamp transaction type merchant_category  \
# 249990  TXN0000249991 2024-01-10 18:15:33              P2P     Entertainment
# 249991  TXN0000249992 2024-11-22 16:46:02              P2M           Grocery
# 249992  TXN0000249993 2024-06-29 19:55:34              P2P          Shopping
# 249993  TXN0000249994 2024-10-01 14:00:36              P2P             Other
# 249994  TXN0000249995 2024-01-07 17:03:09              P2P           Grocery
# 249995  TXN0000249996 2024-11-08 22:41:43         Recharge              Food
# 249996  TXN0000249997 2024-12-15 02:58:03              P2P         Utilities
# 249997  TXN0000249998 2024-11-27 16:33:25              P2P              Food
# 249998  TXN0000249999 2024-01-05 13:31:30         Recharge        Healthcare
# 249999  TXN0000250000 2024-01-17 15:23:07              P2P     Entertainment
#
#         amount (INR) transaction_status sender_age_group receiver_age_group  \
# 249990           188            SUCCESS            46-55              46-55
# 249991           989            SUCCESS            26-35              46-55
# 249992           691            SUCCESS            36-45              36-45
# 249993           131            SUCCESS            26-35              36-45
# 249994          2250            SUCCESS            26-35              26-35
# 249995           373            SUCCESS            36-45              26-35
# 249996          2025            SUCCESS            36-45              26-35
# 249997           468            SUCCESS            26-35              18-25
# 249998           284            SUCCESS            18-25              36-45
# 249999           531            SUCCESS            18-25              26-35
#
#           sender_state sender_bank  ... device_type network_type fraud_flag  \
# 249990       Telangana       Kotak  ...     Android           4G          0
# 249991  Andhra Pradesh       ICICI  ...     Android           4G          0
# 249992  Andhra Pradesh        Axis  ...     Android           5G          0
# 249993     West Bengal         SBI  ...     Android           5G          0
# 249994           Delhi         PNB  ...     Android           4G          0
# 249995       Telangana       ICICI  ...         iOS           5G          0
# 249996       Rajasthan        HDFC  ...     Android           5G          0
# 249997     West Bengal       ICICI  ...     Android           4G          0
# 249998  Andhra Pradesh        Axis  ...         iOS           4G          0
# 249999       Telangana        Axis  ...     Android           4G          0
#
#         hour_of_day  day_of_week is_weekend     Month Time_period  \
# 249990           18    Wednesday          0   January     Evening
# 249991           16       Friday          0  November   Afternoon
# 249992           19     Saturday          1      June     Evening
# 249993           14      Tuesday          0   October   Afternoon
# 249994           17       Sunday          1   January   Afternoon
# 249995           22       Friday          0  November       Night
# 249996            2       Sunday          1  December       Night
# 249997           16    Wednesday          0  November   Afternoon
# 249998           13       Friday          0   January   Afternoon
# 249999           15    Wednesday          0   January   Afternoon
#
#        amount_category Same_Bank_Transaction
# 249990             Low                    No
# 249991          Medium                    No
# 249992          Medium                    No
# 249993             Low                    No
# 249994            High                    No
# 249995             Low                    No
# 249996            High                    No
# 249997             Low                   Yes
# 249998             Low                    No
# 249999             Low                    No
#
# [10 rows x 21 columns]

# %% [markdown]
# # 4. Missing Value Analysis
#
# Identify missing values across all columns and determine whether they require imputation, removal, or no action based on the nature of the data.

# %%
transactions.isnull().sum()
# Out:
# transaction id        0
# timestamp             0
# transaction type      0
# merchant_category     0
# amount (INR)          0
# transaction_status    0
# sender_age_group      0
# receiver_age_group    0
# sender_state          0
# sender_bank           0
# receiver_bank         0
# device_type           0
# network_type          0
# fraud_flag            0
# hour_of_day           0
# day_of_week           0
# is_weekend            0
# dtype: int64

# %% [markdown]
# # 5. Duplicate Detection
#
# Check for duplicate transaction records and duplicate transaction IDs to ensure data integrity before proceeding with the analysis.

# %%
transactions.duplicated().sum()
# Out:
# np.int64(0)

# %%
transactions['transaction id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 6. Data Type Conversion
#
# Convert columns to appropriate data types, particularly the timestamp column, to enable accurate time-based analysis and feature engineering.

# %%
transactions['timestamp'] = pd.to_datetime(transactions['timestamp'])

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   transaction id      250000 non-null  object
#  1   timestamp           250000 non-null  datetime64[ns]
#  2   transaction type    250000 non-null  object
#  3   merchant_category   250000 non-null  object
#  4   amount (INR)        250000 non-null  int64
#  5   transaction_status  250000 non-null  object
#  6   sender_age_group    250000 non-null  object
#  7   receiver_age_group  250000 non-null  object
#  8   sender_state        250000 non-null  object
#  9   sender_bank         250000 non-null  object
#  10  receiver_bank       250000 non-null  object
#  11  device_type         250000 non-null  object
#  12  network_type        250000 non-null  object
#  13  fraud_flag          250000 non-null  int64
#  14  hour_of_day         250000 non-null  int64
#  15  day_of_week         250000 non-null  object
#  16  is_weekend          250000 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(12)
# memory usage: 32.4+ MB

# %%
transactions['Month'] = transactions['timestamp'].dt.month_name()

# %% [markdown]
# # 7. Feature Engineering
#
# Create new analytical features that improve transaction analysis and fraud detection while maintaining the interpretability of the dataset.

# %% [markdown]
# ## 7.1 Time-Based Features
#
# Extract useful temporal information from the transaction timestamp, including month, day, and time period, to support trend analysis and fraud pattern identification.

# %%
hours = [0, 5, 12, 17, 21, 24]
labels = ['Night', 'Morning', 'Afternoon', 'Evening', 'Night']

transactions['Time_period'] = pd.cut(transactions['timestamp'].dt.hour,bins=hours,labels=labels,ordered=False)

# %%
transactions['amount (INR)'].min()
transactions['amount (INR)'].max()
# Out:
# 42099

# %%
print(transactions['amount (INR)'].describe())
# Out:
# count    250000.000000
# mean       1311.756036
# std        1848.059224
# min          10.000000
# 25%         288.000000
# 50%         629.000000
# 75%        1596.000000
# max       42099.000000
# Name: amount (INR), dtype: float64

# %% [markdown]
# ## 7.2 Transaction Amount Features
#
# Categorize transaction amounts into meaningful groups and identify high-value transactions for further business analysis.

# %%
conditions = [
    (transactions['amount (INR)'] <= 600),                      
    (transactions['amount (INR)'] > 600) & (transactions['amount (INR)'] <= 2000),
    (transactions['amount (INR)'] > 2000)                            
]

labels = ['Low', 'Medium', 'High']

transactions['amount_category'] = np.select(conditions, labels,default='Unknown')

# %%
transactions.head(10)
# Out:
#   transaction id           timestamp transaction type merchant_category  \
# 0  TXN0000000001 2024-10-08 15:17:28              P2P     Entertainment
# 1  TXN0000000002 2024-04-11 06:56:00              P2M           Grocery
# 2  TXN0000000003 2024-04-02 13:27:18              P2P           Grocery
# 3  TXN0000000004 2024-01-07 10:09:17              P2P              Fuel
# 4  TXN0000000005 2024-01-23 19:04:23              P2P          Shopping
# 5  TXN0000000006 2024-10-07 22:32:07              P2P              Food
# 6  TXN0000000007 2024-02-08 10:25:57              P2P             Other
# 7  TXN0000000008 2024-10-27 18:47:02              P2P         Utilities
# 8  TXN0000000009 2024-11-21 09:39:16              P2P             Other
# 9  TXN0000000010 2024-11-11 15:58:56              P2M           Grocery
#
#    amount (INR) transaction_status sender_age_group receiver_age_group  \
# 0           868            SUCCESS            26-35              18-25
# 1          1011            SUCCESS            26-35              26-35
# 2           477            SUCCESS            26-35              36-45
# 3          2784            SUCCESS            26-35              26-35
# 4           990            SUCCESS            26-35              18-25
# 5            91            SUCCESS            36-45              18-25
# 6           314            SUCCESS            36-45              18-25
# 7           264            SUCCESS            46-55              36-45
# 8           887            SUCCESS            46-55              36-45
# 9          3260            SUCCESS            46-55              18-25
#
#     sender_state sender_bank receiver_bank device_type network_type  \
# 0          Delhi        Axis           SBI     Android           4G
# 1  Uttar Pradesh       ICICI          Axis         iOS           4G
# 2      Karnataka    Yes Bank           PNB     Android           4G
# 3          Delhi       ICICI           PNB     Android           5G
# 4          Delhi        Axis      Yes Bank         iOS         WiFi
# 5      Karnataka    IndusInd      Yes Bank     Android           3G
# 6      Telangana        HDFC      IndusInd     Android           4G
# 7    Maharashtra    Yes Bank           SBI     Android           5G
# 8    Maharashtra       Kotak          HDFC     Android           4G
# 9          Delhi         SBI          HDFC     Android           4G
#
#    fraud_flag  hour_of_day day_of_week  is_weekend     Month Time_period  \
# 0           0           15     Tuesday           0   October   Afternoon
# 1           0            6    Thursday           0     April     Morning
# 2           0           13     Tuesday           0     April   Afternoon
# 3           0           10      Sunday           1   January     Morning
# 4           0           19     Tuesday           0   January     Evening
# 5           0           22      Monday           0   October       Night
# 6           0           10    Thursday           0  February     Morning
# 7           0           18      Sunday           1   October     Evening
# 8           0            9    Thursday           0  November     Morning
# 9           0           15      Monday           0  November   Afternoon
#
#   amount_category
# 0          Medium
# 1          Medium
# 2             Low
# 3            High
# 4          Medium
# 5             Low
# 6             Low
# 7             Low
# 8          Medium
# 9            High

# %%
transactions['Same_Bank_Transaction'] = np.where(transactions['sender_bank'] == transactions['receiver_bank'],'Yes','No')

# %% [markdown]
# # 8. Data Validation
#
# The purpose of this section is to verify that the cleaned dataset is accurate, consistent, and ready for analysis. The following validation checks are performed to ensure there are no invalid values, incorrect categories, or inconsistencies remaining after data cleaning and feature engineering.

# %%
# Transaction Amount Validation
minimun = transactions['amount (INR)'].min()
maximun = transactions['amount (INR)'].max()

print(minimun,maximun)
# Out:
# 10 42099

# %%
# Fraud Flag Validation
transactions['fraud_flag'].value_counts()
# Out:
# fraud_flag
# 0    249520
# 1       480
# Name: count, dtype: int64

# %%
# Hour Validation
min_hour = transactions['hour_of_day'].min()
max_hour = transactions['hour_of_day'].max()

print(min_hour,max_hour)
# Out:
# 0 23

# %%
# Weekend Validation
transactions['is_weekend'].value_counts()
# Out:
# is_weekend
# 0    178663
# 1     71337
# Name: count, dtype: int64

# %%
transactions['transaction_status'].value_counts()
# Out:
# transaction_status
# SUCCESS    237624
# FAILED      12376
# Name: count, dtype: int64

# %%
transactions.shape

transactions.info()

transactions.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   transaction id         250000 non-null  object
#  1   timestamp              250000 non-null  datetime64[ns]
#  2   transaction type       250000 non-null  object
#  3   merchant_category      250000 non-null  object
#  4   amount (INR)           250000 non-null  int64
#  5   transaction_status     250000 non-null  object
#  6   sender_age_group       250000 non-null  object
#  7   receiver_age_group     250000 non-null  object
#  8   sender_state           250000 non-null  object
#  9   sender_bank            250000 non-null  object
#  10  receiver_bank          250000 non-null  object
#  11  device_type            250000 non-null  object
#  12  network_type           250000 non-null  object
#  13  fraud_flag             250000 non-null  int64
#  14  hour_of_day            250000 non-null  int64
#  15  day_of_week            250000 non-null  object
#  16  is_weekend             250000 non-null  int64
#  17  Month                  250000 non-null  object
#  18  Time_period            246612 non-null  category
#  19  amount_category        250000 non-null  object
#  20  Same_Bank_Transaction  250000 non-null  object
# dtypes: category(1), datetime64[ns](1), int64(4), object(15)
# memory usage: 38.4+ MB
#   transaction id           timestamp transaction type merchant_category  \
# 0  TXN0000000001 2024-10-08 15:17:28              P2P     Entertainment
# 1  TXN0000000002 2024-04-11 06:56:00              P2M           Grocery
# 2  TXN0000000003 2024-04-02 13:27:18              P2P           Grocery
# 3  TXN0000000004 2024-01-07 10:09:17              P2P              Fuel
# 4  TXN0000000005 2024-01-23 19:04:23              P2P          Shopping
#
#    amount (INR) transaction_status sender_age_group receiver_age_group  \
# 0           868            SUCCESS            26-35              18-25
# 1          1011            SUCCESS            26-35              26-35
# 2           477            SUCCESS            26-35              36-45
# 3          2784            SUCCESS            26-35              26-35
# 4           990            SUCCESS            26-35              18-25
#
#     sender_state sender_bank  ... device_type network_type fraud_flag  \
# 0          Delhi        Axis  ...     Android           4G          0
# 1  Uttar Pradesh       ICICI  ...         iOS           4G          0
# 2      Karnataka    Yes Bank  ...     Android           4G          0
# 3          Delhi       ICICI  ...     Android           5G          0
# 4          Delhi        Axis  ...         iOS         WiFi          0
#
#    hour_of_day  day_of_week is_weekend    Month Time_period amount_category  \
# 0           15      Tuesday          0  October   Afternoon          Medium
# 1            6     Thursday          0    April     Morning          Medium
# 2           13      Tuesday          0    April   Afternoon             Low
# 3           10       Sunday          1  January     Morning            High
# 4           19      Tuesday          0  January     Evening          Medium
#
#   Same_Bank_Transaction
# 0                    No
# 1                    No
# 2                    No
# 3                    No
# 4                    No
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Validation Summary
#
# The dataset has successfully passed all validation checks. No critical inconsistencies, invalid records, or missing values remain after data cleaning and feature engineering. The dataset is now ready for exploratory data analysis (EDA), SQL analysis, Power BI dashboard development, and the machine learning phase.

# %% [markdown]
# # 9. Export Clean Dataset
#
# Save the cleaned and feature-engineered dataset for use in subsequent phases, including Exploratory Data Analysis (EDA), SQL analysis, Power BI dashboard development, and Machine Learning.

# %%
transactions.to_csv('../Data/transactions_cleaned.csv',index=False)
